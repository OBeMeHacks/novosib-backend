# %%
from finance_model import Model

# %%
model = Model(
    'data/external_features.frt',
    'data/npo_clnts.csv',
    'data/npo_cntrbtrs.csv',
    'data/correct_target.frt'
)
# Out:
# Learning rate set to 0.142813
# 0:	learn: 2225.4575761	total: 119ms	remaining: 1m 58s
# 1:	learn: 2188.0460392	total: 181ms	remaining: 1m 30s
# 2:	learn: 2159.4967069	total: 240ms	remaining: 1m 19s
# 3:	learn: 2136.7870881	total: 303ms	remaining: 1m 15s
# 4:	learn: 2119.0155101	total: 364ms	remaining: 1m 12s
# 5:	learn: 2105.3776359	total: 427ms	remaining: 1m 10s
# 6:	learn: 2094.3163654	total: 486ms	remaining: 1m 8s
# 7:	learn: 2084.1798750	total: 554ms	remaining: 1m 8s
# 8:	learn: 2075.9683893	total: 616ms	remaining: 1m 7s
# 9:	learn: 2069.9045643	total: 680ms	remaining: 1m 7s
# 10:	learn: 2064.6762728	total: 740ms	remaining: 1m 6s
# 11:	learn: 2060.3983700	total: 803ms	remaining: 1m 6s
# 12:	learn: 2055.6968331	total: 867ms	remaining: 1m 5s
# 13:	learn: 2052.4010721	total: 930ms	remaining: 1m 5s
# 14:	learn: 2048.8011946	total: 998ms	remaining: 1m 5s
# 15:	learn: 2046.5830642	total: 1.06s	remaining: 1m 5s
# 16:	learn: 2044.0111371	total: 1.13s	remaining: 1m 5s
# ...

# %%
client_ids = open("test.txt").read().split()

predictions: list[tuple[int, int]] = [model.predict(client_id) for client_id in client_ids] # mean, count
